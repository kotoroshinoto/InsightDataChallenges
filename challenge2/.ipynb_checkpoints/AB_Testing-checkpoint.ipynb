# %%
from utility_funcs import fix_date_time
import pandas as pd
import numpy as np
import seaborn as sn
import scipy as sp
import matplotlib.pyplot as plt
import reverse_geocoder as rg
from sklearn.feature_selection import chi2
from sklearn.preprocessing import LabelEncoder
from scipy.stats import ttest_ind
from sklearn.naive_bayes import MultinomialNB
from math import pow, sqrt
from scipy.stats import mannwhitneyu, binom_test, chisquare, chi2_contingency

# %%
filepath = 'test_results.csv'
outpath = 'fixed_test_results.csv'
# fix_date_time(filepath=filepath, outpath=outpath)

# %%
test_df = pd.DataFrame.from_csv('fixed_test_results.csv')
test_df['timestamp'] = pd.to_datetime(test_df['timestamp'])
user_df = pd.DataFrame.from_csv('user_table.csv')

# %%
where_control = test_df.where(test_df['test'] == 0)
where_test = test_df.where(test_df['test'] == 1)
invalid_control = ~((where_control['price'] == 39) | pd.isnull(where_control['price']))
invalid_test = ~((where_test['price'] == 59) | pd.isnull(where_test['price']))
valid_test_or_control = ~(invalid_control | invalid_test)
dropped_invalid_df = test_df.where(~valid_test_or_control).dropna(how='all')
test_df = test_df.where(valid_test_or_control).dropna(how='all')
test_df.reset_index(level=0, inplace=True)
user_df.reset_index(level=0, inplace=True)
df = test_df.merge(user_df, on='user_id')
df.test = df.test.astype(int)
df.converted = df.converted.astype(int)

# %%
# df.timestamp.dt.minute
# df.timestamp.dt.month
# df.timestamp.dt.hour
df.columns
admin1 = []
admin2 = []
country = []
user_id = df.user_id
geosearch = rg.search(list(zip(df.lat, df.long)))
weird = ['Nunavut', 'St.-Petersburg', ]
index = 0
for item in geosearch:
    admin1.append(item['admin1'])
    admin2.append(item['admin2'])
    country.append(item['cc'])
    # if item['admin1'] in weird:
    #     print(item)
geocode_df = pd.DataFrame()
geocode_df['user_id']=user_id
admin1 = pd.Series(admin1)
admin2 = pd.Series(admin2)
country = pd.Series(country)
# admin1.unique()
# df[['lat', 'long']]
geocode_df['State'] = admin1
geocode_df['rg_country'] = country

combdf = df.merge(geocode_df, on=['user_id'])
non_usa = combdf.where(combdf['rg_country'] != 'US').dropna(how='all').copy()
fixeddf = combdf.where(combdf['rg_country'] == 'US').dropna(how='all').copy()
print(fixeddf.shape)
print(non_usa.shape)
# st_l = fixeddf.State.unique()
# for st in ["Alabama", "Alaska", "Arizona", "Arkansas",  "California", "Colorado", "Connecticut", "Delaware", "Florida", "Georgia", "Hawaii", "Idaho", "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", "New Hampshire", "New Jersey", "New Mexico", "New York", "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", "West Virginia", "Wisconsin", "Wyoming"]:
#     if st not in st_l:
#         print(st)
fixeddf['city_state'] = fixeddf.city.map(str) + '_' + fixeddf.State
df = fixeddf
df['hour_of_day'] = df.timestamp.dt.hour
df['month_of_year'] = df.timestamp.dt.month
# Out:
# (274765, 14)
# (529, 14)

# %%
df.loc()[0:20]
# Out:
#      user_id           timestamp           source  device operative_system  \
# 0   604839.0 2015-05-08 03:38:34     ads_facebook  mobile              iOS
# 1   624057.0 2015-05-10 21:08:46       seo-google  mobile          android
# 2   317970.0 2015-04-04 15:01:23         ads-bing  mobile          android
# 3   685636.0 2015-05-07 07:26:01   direct_traffic  mobile              iOS
# 4   820854.0 2015-05-24 11:04:40     ads_facebook     web              mac
# 5   169971.0 2015-04-13 12:07:08       ads-google  mobile              iOS
# 6   798371.0 2015-03-15 08:19:29         ads-bing  mobile          android
# 7   447194.0 2015-03-28 12:28:10     ads_facebook     web          windows
# 8   431639.0 2015-04-24 12:42:18     ads_facebook     web          windows
# 9   590182.0 2015-04-17 13:30:04       ads-google     web          windows
# 10  606479.0 2015-05-15 12:36:46   direct_traffic     web              mac
# 11  460593.0 2015-03-21 09:43:51  friend_referral  mobile              iOS
# 12  708831.0 2015-05-29 08:19:24       ads-google  mobile              iOS
# 13  552048.0 2015-03-22 08:58:32         ads-bing     web          windows
# 14  444108.0 2015-03-16 12:20:49       seo-google     web              mac
# 15  692331.0 2015-03-08 13:19:55       ads-google  mobile              iOS
# 16  599771.0 2015-03-28 18:41:37   direct_traffic  mobile              iOS
# 17  817127.0 2015-03-04 15:52:29     ads_facebook  mobile              iOS
# 18  747762.0 2015-04-04 23:10:20     ads_facebook  mobile              iOS
# 19  672422.0 2015-05-31 10:29:32        ads_other     web          windows
# 20  110040.0 2015-05-16 02:31:27       ads-google     web              mac
#
#     test  price  converted                 city country    lat    long  \
# 0    0.0   39.0        0.0              Buffalo     USA  42.89  -78.86
# 1    0.0   39.0        0.0            Lakeville     USA  44.68  -93.24
# 2    0.0   39.0        0.0                Parma     USA  41.38  -81.73
# 3    1.0   59.0        0.0         Fayetteville     USA  35.07  -78.90
# 4    0.0   39.0        0.0              Fishers     USA  39.95  -86.02
# 5    0.0   39.0        0.0             New York     USA  40.67  -73.94
# 6    1.0   59.0        1.0          East Orange     USA  40.77  -74.21
# 7    1.0   59.0        0.0               Dayton     USA  39.78  -84.20
# 8    1.0   59.0        0.0             Richmond     USA  37.53  -77.47
# 9    0.0   39.0        0.0  Bloomfield Township     USA  42.58  -83.27
# 10   0.0   39.0        0.0          Des Plaines     USA  42.03  -87.90
# 11   0.0   39.0        1.0              Hampton     USA  37.05  -76.29
# 12   0.0   39.0        0.0     West Valley City     USA  40.69 -112.01
# 13   1.0   59.0        0.0          Culver City     USA  34.01 -118.40
# 14   0.0   39.0        0.0            Milwaukee     USA  43.06  -87.97
# 15   0.0   39.0        0.0      Deerfield Beach     USA  26.31  -80.12
# 16   1.0   59.0        0.0              Chicago     USA  41.84  -87.68
# 17   0.0   39.0        0.0            Sheboygan     USA  43.75  -87.73
# 18   0.0   39.0        0.0             New York     USA  40.67  -73.94
# 19   0.0   39.0        0.0             New York     USA  40.67  -73.94
# 20   0.0   39.0        0.0                 Mesa     USA  33.42 -111.74
#
#              State rg_country                    city_state  hour_of_day  \
# 0         New York         US              Buffalo_New York            3
# 1        Minnesota         US           Lakeville_Minnesota           21
# 2             Ohio         US                    Parma_Ohio           15
# 3   North Carolina         US   Fayetteville_North Carolina            7
# 4          Indiana         US               Fishers_Indiana           11
# 5         New York         US             New York_New York           12
# 6       New Jersey         US        East Orange_New Jersey            8
# 7             Ohio         US                   Dayton_Ohio           12
# 8         Virginia         US             Richmond_Virginia           12
# 9         Michigan         US  Bloomfield Township_Michigan           13
# 10        Illinois         US          Des Plaines_Illinois           12
# 11        Virginia         US              Hampton_Virginia            9
# 12            Utah         US         West Valley City_Utah            8
# 13      California         US        Culver City_California            8
# 14       Wisconsin         US           Milwaukee_Wisconsin           12
# 15         Florida         US       Deerfield Beach_Florida           13
# 16        Illinois         US              Chicago_Illinois           18
# 17       Wisconsin         US           Sheboygan_Wisconsin           15
# 18        New York         US             New York_New York           23
# 19        New York         US             New York_New York           10
# 20         Arizona         US                  Mesa_Arizona            2
#
#     month_of_year
# 0               5
# 1               5
# 2               4
# 3               5
# 4               5
# 5               4
# 6               3
# 7               3
# 8               4
# 9               4
# 10              5
# 11              3
# 12              5
# 13              3
# 14              3
# 15              3
# 16              3
# 17              3
# 18              4
# 19              5
# 20              5

# %%
def compute_results_features(df):
    results_df = pd.DataFrame()
    results_df['class'] = pd.Series(['Control', 'Test'])
    results_df['Visitors'] = df.groupby(['test'])['user_id'].count()
    results_df['CountConverted'] = df.groupby(df['test'])['converted'].sum()
    results_df['SalesRevenue'] = df.groupby(['test'])['price'].sum()
    results_df['ConvertRate'] = results_df.CountConverted / results_df.Visitors
    results_df['price'] = pd.Series([39, 59])
    results_df['RevenueRate'] = results_df.ConvertRate * results_df.price
    results_df['sigma_rate']= np.sqrt((results_df.ConvertRate * (1 - results_df.ConvertRate)) / results_df.Visitors)
    results_df.set_index(['class'], inplace=True)
    return results_df


results_df = compute_results_features(df)
results_df
# Out:
#          Visitors  CountConverted  SalesRevenue  ConvertRate  price  \
# class
# Control    175933          3482.0     6861387.0     0.019792     39
# Test        98832          1526.0     5831088.0     0.015440     59
#
#          RevenueRate  sigma_rate
# class
# Control     0.771873    0.000332
# Test        0.910980    0.000392

# %%
def test_results_distros(results_df):
    converts = results_df.CountConverted
    nonconverts = results_df.Visitors - results_df.CountConverted
    rates = results_df.ConvertRate
    print("binomial test same rates: control: %0.3e, test: %0.3e" % (
        binom_test([converts[0], nonconverts[0]], p=rates[0]), 
     binom_test([converts[1], nonconverts[1]], p=rates[1])))
    print("binomial test, opposite rates: %0.3e, test: %0.3e" % (
        binom_test([converts[0], nonconverts[0]], p=rates[1]), 
     binom_test([converts[1], nonconverts[1]], p=rates[0])))
    # mannwhitneyu(df.where(df.test == 1).dropna(how='all').converted, 
    #              df.where(df.test == 0).dropna(how='all').converted)
    
    chidf = pd.DataFrame()
    chidf['success'] = converts
    chidf['failure'] = nonconverts
    chiresultdf = pd.DataFrame()
    chires = chi2_contingency(chidf)
    restbl = chires[3]
    chiresultdf['class'] = ['Control', 'Test']
    chiresultdf.set_index(['class'], inplace=True)
    chiresultdf['success'] = [restbl[0][0], restbl[1][0]]
    chiresultdf['failure'] = [restbl[0][1], restbl[1][1]]
    print("statistic: %0.3f\np=%0.3e\ndeg_free:%d\nexpected: %s" % (chires[0], chires[1], chires[2], chiresultdf))
test_results_distros(results_df)
# Out:
# binomial test same rates: control: 1.000e+00, test: 1.000e+00
# binomial test, opposite rates: 1.065e-45, test: 2.114e-24
# statistic: 66.715
# p=3.137e-16
# deg_free:1
# expected:              success        failure
# class
# Control  3206.640089  172726.359911
# Test     1801.359911   97030.640089

# %%
from floatrange import floatrange
from math import log10
def plot_dist_p_probs(results_df, factor=3):
    converts = results_df.CountConverted
    nonconverts = results_df.Visitors - results_df.CountConverted
    rates = results_df.ConvertRate
    xval = []
    cy = []
    vy = []
    for f in floatrange(min(rates), max(rates), (10 ** (int(log10(min(rates))) - factor))):
        xval.append(f)
        cy.append(binom_test([converts[0], nonconverts[0]], p=f))
        vy.append(binom_test([converts[1], nonconverts[1]], p=f))
    cprobs = pd.DataFrame()
    cprobs['P']=xval
    cprobs['p_binom_with_P'] = cy
    cprobs['group'] = 'control'
    vprobs = pd.DataFrame()
    vprobs['P']=xval
    vprobs['p_binom_with_P'] = vy
    vprobs['group'] = 'test'
    probs = pd.concat([cprobs, vprobs])
#     return probs
    facets = sn.lmplot(x='P', y='p_binom_with_P', data=probs, hue='group', fit_reg=False, aspect=2)
    facets.ax.set_xlim([0.015,0.020])
    plt.show()
plot_dist_p_probs(results_df, 4)

# %%
control_price = 39
test_price = 59
conversion_rate = 3484.0 / 176241.0
actual_new_rate = 1530.0 / 99053.0
print((actual_new_rate - conversion_rate )/conversion_rate)
#newConvRate = price*rate/new_rate
break_even = (control_price*conversion_rate)/test_price 
print((break_even - conversion_rate )/conversion_rate)
print(break_even) 
print(break_even * test_price)
print(conversion_rate * control_price)
rate_diff = abs(break_even - conversion_rate) 
rate_diff_percent = rate_diff / conversion_rate
print(rate_diff)
print(rate_diff_percent)
print(abs(actual_new_rate-conversion_rate)/conversion_rate)
# Out:
# -0.21863743682524253
# -0.3389830508474576
# 0.013067237764467166
# 0.7709670281035628
# 0.7709670281035628
# 0.006701147571521623
# 0.3389830508474576
# 0.21863743682524253

# %%
from statsmodels.stats.power import GofChisquarePower
from statsmodels.stats.gof import chisquare_effectsize
chisqp = GofChisquarePower()
effect_size_break_even = sqrt(abs((break_even-conversion_rate)**2)/conversion_rate)
num_samp = chisqp.solve_power(effect_size=effect_size_break_even/2, alpha=0.05, n_bins=2, power=0.90)
corrected_num_samp = int(num_samp) + int((num_samp - int(num_samp)) > 0)
print(corrected_num_samp)
# Out:
# 18503

# %%
from typing import Dict, List, Tuple
from sklearn.preprocessing import LabelEncoder
#make feature array for training a model
#check device, OS, city, source, hour of day
X = df[['timestamp', 'source', 'device', 'operative_system', 'city', 'State']].copy()
X['hour_of_day'] = X.timestamp.dt.hour
X['month_of_year'] = X.timestamp.dt.month
del X['timestamp']
X['city_state'] = X.city.map(str) + '_' + X.State
del X['city']
lbl_encs = dict()  # type: Dict['str', LabelEncoder]
for col in ['source', 'device', 'operative_system', 'city_state', 'State']:
    lbl_encs[col] = LabelEncoder()
    X[col] = lbl_encs[col].fit_transform(X[col])

Y = df.converted

# %%
X
# Out:
#         source  device  operative_system  State  hour_of_day  month_of_year  \
# 0            3       0                 1     31            3              5
# 1            8       0                 0     22           21              5
# 2            0       0                 0     34           15              4
# 3            5       0                 1     32            7              5
# 4            3       1                 3     13           11              5
# 5            1       0                 1     31           12              4
# 6            0       0                 0     29            8              3
# 7            3       1                 5     34           12              3
# 8            3       1                 5     44           12              4
# 9            1       1                 5     21           13              4
# 10           5       1                 3     12           12              5
# 11           6       0                 1     44            9              3
# 12           1       0                 1     43            8              5
# 13           0       1                 5      4            8              3
# 14           8       1                 3     48           12              3
# 15           1       0                 1      8           13              3
# 16           5       0                 1     12           18              3
# 17           3       0                 1     48           15              3
# 18           3       0                 1     31           23              4
# 19           4       1                 5     31           10              5
# 20           1       1                 3      2            2              5
# 21           5       0                 0     12           11              3
# 22           2       0                 1     41           11              3
# 23           3       1                 5      4           15              4
# 24           1       1                 5     19            7              5
# 25           4       1                 5     29           13              3
# 26           3       0                 1      4            8              3
# 27           5       0                 1      4            6              5
# 28           4       0                 1     39           11              4
# 29           4       0                 4     27            5              5
# ...        ...     ...               ...    ...          ...            ...
# 275264       5       1                 5     12           16              4
# 275265       6       0                 0     42            8              5
# 275266       3       0                 1      8           11              5
# 275267       3       0                 1      4            8              3
# 275268       5       1                 5      4            5              4
# 275269       5       1                 5     29           18              5
# 275270       3       0                 0     37           17              3
# 275271       1       0                 0     20           11              5
# 275272       0       0                 1     19            9              4
# 275273       4       0                 0     26           14              5
# 275274       0       0                 1     44           12              4
# 275275      11       0                 0      6           12              5
# 275276       8       1                 5      4            9              4
# 275277       5       1                 5     31           12              4
# 275278       1       0                 1     31           23              5
# 275279       8       0                 1     34            5              4
# 275280       4       1                 5      9           13              5
# 275281       1       0                 1     41            9              3
# 275282       3       0                 1     29            9              3
# 275283       3       0                 1     41           16              3
# 275284       6       0                 1      4           22              3
# 275285       5       0                 1      8            8              5
# 275286       0       1                 5     26           20              3
# 275287      11       1                 5     37           15              5
# 275288      10       0                 1     42           10              4
# 275289       8       1                 5     12           11              5
# 275290       5       1                 5      4           23              3
# 275291       1       1                 3     31            1              4
# 275292       6       0                 0      4            5              5
# 275293       3       0                 0     12           17              3
#
#         city_state
# 0              122
# 1              465
# 2              660
# 3              303
# 4              306
# 5              597
# 6              262
# 7              228
# 8              739
# 9               83
# 10             244
# 11             375
# 12             960
# 13             215
# 14             554
# 15             236
# 16             169
# 17             821
# 18             597
# 19             597
# 20             542
# 21             942
# 22             427
# 23             628
# 24             342
# 25              40
# 26             725
# 27             729
# 28             612
# 29             477
# ...            ...
# 275264         169
# 275265         321
# 275266         400
# 275267         741
# 275268         147
# 275269         609
# 275270         513
# 275271         962
# 275272         189
# 275273         495
# 275274         861
# 275275         593
# 275276         621
# 275277         597
# 275278         597
# 275279         600
# 275280          38
# 275281         178
# 275282         609
# 275283         587
# 275284         344
# 275285         648
# 275286         636
# 275287         679
# 275288         663
# 275289         428
# 275290          64
# 275291         959
# 275292         930
# 275293         169
#
# [274765 rows x 7 columns]

# %%
# Y

# %%
mnb = MultinomialNB()
mnb.fit(X, Y)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier().fit(X,Y)

# %%
features = pd.DataFrame()
features['names'] = X.columns
features['importance']=clf.feature_importances_
features
# Out:
#               names  importance
# 0            source    0.085036
# 1            device    0.013638
# 2  operative_system    0.025079
# 3             State    0.122312
# 4       hour_of_day    0.288392
# 5     month_of_year    0.118147
# 6        city_state    0.347396

# %%
from sklearn.linear_model import SGDClassifier
alpha = 1e-4
l1_ratio = 0.33
l1sgd = SGDClassifier(penalty='l1', loss='log', alpha=alpha, l1_ratio=l1_ratio)
l2sgd = SGDClassifier(penalty='l2', loss='log', alpha=alpha, l1_ratio=l1_ratio)
elastsgd = SGDClassifier(penalty='elasticnet', loss='log', alpha=alpha, l1_ratio=l1_ratio)
l1sgd.fit(X,Y)
l2sgd.fit(X,Y)
elastsgd.fit(X,Y)
features['l1sgd_coef'] = l1sgd.coef_[0]
features['l2sgd_coef'] = l2sgd.coef_[0]
features['elastsgd_coef'] = elastsgd.coef_[0]
features
# Out:
#               names  importance  l1sgd_coef  l2sgd_coef  elastsgd_coef
# 0            source    0.085036    0.000000   -0.809936       0.000000
# 1            device    0.013638    0.000000    0.847777       0.000000
# 2  operative_system    0.025079    0.000000   -3.264915      -1.510557
# 3             State    0.122312    0.000000    0.142970       0.000000
# 4       hour_of_day    0.288392    0.000000   -0.642607       0.000000
# 5     month_of_year    0.118147   -0.212132   -1.656408       1.674826
# 6        city_state    0.347396   -0.467864   -3.403586       0.000000

# %%
cdf = df.where(df.converted == 1).dropna(how='all')
ucdf = df.where(df.converted == 0).dropna(how='all')
ucdf
# Out:
#          user_id           timestamp           source  device  \
# 0       604839.0 2015-05-08 03:38:34     ads_facebook  mobile
# 1       624057.0 2015-05-10 21:08:46       seo-google  mobile
# 2       317970.0 2015-04-04 15:01:23         ads-bing  mobile
# 3       685636.0 2015-05-07 07:26:01   direct_traffic  mobile
# 4       820854.0 2015-05-24 11:04:40     ads_facebook     web
# 5       169971.0 2015-04-13 12:07:08       ads-google  mobile
# 7       447194.0 2015-03-28 12:28:10     ads_facebook     web
# 8       431639.0 2015-04-24 12:42:18     ads_facebook     web
# 9       590182.0 2015-04-17 13:30:04       ads-google     web
# 10      606479.0 2015-05-15 12:36:46   direct_traffic     web
# 12      708831.0 2015-05-29 08:19:24       ads-google  mobile
# 13      552048.0 2015-03-22 08:58:32         ads-bing     web
# 14      444108.0 2015-03-16 12:20:49       seo-google     web
# 15      692331.0 2015-03-08 13:19:55       ads-google  mobile
# 16      599771.0 2015-03-28 18:41:37   direct_traffic  mobile
# 17      817127.0 2015-03-04 15:52:29     ads_facebook  mobile
# 18      747762.0 2015-04-04 23:10:20     ads_facebook  mobile
# 19      672422.0 2015-05-31 10:29:32        ads_other     web
# 20      110040.0 2015-05-16 02:31:27       ads-google     web
# 21      833161.0 2015-03-05 11:32:28   direct_traffic  mobile
# 22      418796.0 2015-03-28 11:33:35        ads-yahoo  mobile
# 23      700829.0 2015-04-25 15:13:26     ads_facebook     web
# 24      135703.0 2015-05-31 07:50:23       ads-google     web
# 25      560795.0 2015-03-22 13:26:12        ads_other     web
# 26      227627.0 2015-03-15 08:34:28     ads_facebook  mobile
# 27      921058.0 2015-05-23 06:47:55   direct_traffic  mobile
# 28      640347.0 2015-04-17 11:02:06        ads_other  mobile
# 29      314759.0 2015-05-01 05:18:29        ads_other  mobile
# 30      868703.0 2015-04-17 09:52:14       ads-google     web
# 31      281123.0 2015-05-01 05:21:34        seo-yahoo     web
# ...          ...                 ...              ...     ...
# 275264  344683.0 2015-04-18 16:55:53   direct_traffic     web
# 275265  858083.0 2015-05-22 08:29:46  friend_referral  mobile
# 275266  361396.0 2015-05-16 11:26:07     ads_facebook  mobile
# 275267  162757.0 2015-03-31 08:15:22     ads_facebook  mobile
# 275268   17844.0 2015-04-10 05:31:25   direct_traffic     web
# 275269  738987.0 2015-05-23 18:00:03   direct_traffic     web
# 275270  364315.0 2015-03-07 17:15:27     ads_facebook  mobile
# 275271  444332.0 2015-05-19 11:58:20       ads-google  mobile
# 275272   41735.0 2015-04-17 09:54:08         ads-bing  mobile
# 275273  278137.0 2015-05-25 14:51:23        ads_other  mobile
# 275274  828924.0 2015-04-30 12:25:55         ads-bing  mobile
# 275275  190563.0 2015-05-17 12:03:19     seo_facebook  mobile
# 275276  796427.0 2015-04-02 09:33:18       seo-google     web
# 275277  267582.0 2015-04-06 12:24:29   direct_traffic     web
# 275278  444264.0 2015-05-31 23:52:41       ads-google  mobile
# 275279  116281.0 2015-04-12 05:32:14       seo-google  mobile
# 275280  964001.0 2015-05-05 13:31:19        ads_other     web
# 275281  757423.0 2015-03-15 09:44:03       ads-google  mobile
# 275282  344235.0 2015-03-06 09:29:23     ads_facebook  mobile
# 275283  466887.0 2015-03-13 16:58:45     ads_facebook  mobile
# 275284  654257.0 2015-03-21 22:02:44  friend_referral  mobile
# 275285  345704.0 2015-05-29 08:08:58   direct_traffic  mobile
# 275286  108465.0 2015-03-29 20:25:55         ads-bing     web
# 275287   26514.0 2015-05-26 15:55:08     seo_facebook     web
# 275288  680578.0 2015-04-24 10:13:45        seo-yahoo  mobile
# 275289  388438.0 2015-05-20 11:34:44       seo-google     web
# 275290  687787.0 2015-03-16 23:31:55   direct_traffic     web
# 275291  618863.0 2015-04-11 01:35:19       ads-google     web
# 275292  154636.0 2015-05-14 05:46:42  friend_referral  mobile
# 275293  832372.0 2015-03-08 17:12:33     ads_facebook  mobile
#
#        operative_system  test  price  converted                 city country  \
# 0                   iOS   0.0   39.0        0.0              Buffalo     USA
# 1               android   0.0   39.0        0.0            Lakeville     USA
# 2               android   0.0   39.0        0.0                Parma     USA
# 3                   iOS   1.0   59.0        0.0         Fayetteville     USA
# 4                   mac   0.0   39.0        0.0              Fishers     USA
# 5                   iOS   0.0   39.0        0.0             New York     USA
# 7               windows   1.0   59.0        0.0               Dayton     USA
# 8               windows   1.0   59.0        0.0             Richmond     USA
# 9               windows   0.0   39.0        0.0  Bloomfield Township     USA
# 10                  mac   0.0   39.0        0.0          Des Plaines     USA
# 12                  iOS   0.0   39.0        0.0     West Valley City     USA
# 13              windows   1.0   59.0        0.0          Culver City     USA
# 14                  mac   0.0   39.0        0.0            Milwaukee     USA
# 15                  iOS   0.0   39.0        0.0      Deerfield Beach     USA
# 16                  iOS   1.0   59.0        0.0              Chicago     USA
# 17                  iOS   0.0   39.0        0.0            Sheboygan     USA
# 18                  iOS   0.0   39.0        0.0             New York     USA
# 19              windows   0.0   39.0        0.0             New York     USA
# 20                  mac   0.0   39.0        0.0                 Mesa     USA
# 21              android   1.0   59.0        0.0             Waukegan     USA
# 22                  iOS   1.0   59.0        0.0         Johnson City     USA
# 23              windows   0.0   39.0        0.0              Oakland     USA
# 24              windows   1.0   59.0        0.0           Germantown     USA
# 25              windows   1.0   59.0        0.0        Atlantic City     USA
# 26                  iOS   1.0   59.0        0.0              Redding     USA
# 27                  iOS   0.0   39.0        0.0        Redondo Beach     USA
# 28                  iOS   0.0   39.0        0.0     North Charleston     USA
# 29                other   0.0   39.0        0.0            Las Vegas     USA
# 30              windows   1.0   59.0        0.0              Kenosha     USA
# 31              windows   0.0   39.0        0.0              La Mesa     USA
# ...                 ...   ...    ...        ...                  ...     ...
# 275264          windows   0.0   39.0        0.0              Chicago     USA
# 275265          android   0.0   39.0        0.0           Fort Worth     USA
# 275266              iOS   0.0   39.0        0.0            Hollywood     USA
# 275267              iOS   0.0   39.0        0.0            Riverside     USA
# 275268          windows   1.0   59.0        0.0       Cathedral City     USA
# 275269          windows   0.0   39.0        0.0         North Bergen     USA
# 275270          android   1.0   59.0        0.0         Lower Merion     USA
# 275271          android   0.0   39.0        0.0            Westfield     USA
# 275272              iOS   0.0   39.0        0.0             Columbia     USA
# 275273          android   1.0   59.0        0.0              Lincoln     USA
# 275274              iOS   1.0   59.0        0.0              Suffolk     USA
# 275275          android   1.0   59.0        0.0            New Haven     USA
# 275276          windows   1.0   59.0        0.0              Norwalk     USA
# 275277          windows   0.0   39.0        0.0             New York     USA
# 275278              iOS   0.0   39.0        0.0             New York     USA
# 275279              iOS   0.0   39.0        0.0               Newark     USA
# 275280          windows   1.0   59.0        0.0        Athens-Clarke     USA
# 275281              iOS   0.0   39.0        0.0          Clarksville     USA
# 275282              iOS   0.0   39.0        0.0         North Bergen     USA
# 275283              iOS   0.0   39.0        0.0            Nashville     USA
# 275284              iOS   0.0   39.0        0.0               Gilroy     USA
# 275285              iOS   0.0   39.0        0.0             Palm Bay     USA
# 275286          windows   0.0   39.0        0.0                Omaha     USA
# 275287          windows   0.0   39.0        0.0         Philadelphia     USA
# 275288              iOS   0.0   39.0        0.0             Pasadena     USA
# 275289          windows   1.0   59.0        0.0               Joliet     USA
# 275290          windows   0.0   39.0        0.0         Bell Gardens     USA
# 275291              mac   0.0   39.0        0.0          West Seneca     USA
# 275292          android   0.0   39.0        0.0         Walnut Creek     USA
# 275293          android   1.0   59.0        0.0              Chicago     USA
#
#           lat    long           State rg_country  \
# 0       42.89  -78.86        New York         US
# 1       44.68  -93.24       Minnesota         US
# 2       41.38  -81.73            Ohio         US
# 3       35.07  -78.90  North Carolina         US
# 4       39.95  -86.02         Indiana         US
# 5       40.67  -73.94        New York         US
# 7       39.78  -84.20            Ohio         US
# 8       37.53  -77.47        Virginia         US
# 9       42.58  -83.27        Michigan         US
# 10      42.03  -87.90        Illinois         US
# 12      40.69 -112.01            Utah         US
# 13      34.01 -118.40      California         US
# 14      43.06  -87.97       Wisconsin         US
# 15      26.31  -80.12         Florida         US
# 16      41.84  -87.68        Illinois         US
# 17      43.75  -87.73       Wisconsin         US
# 18      40.67  -73.94        New York         US
# 19      40.67  -73.94        New York         US
# 20      33.42 -111.74         Arizona         US
# 21      42.37  -87.87        Illinois         US
# 22      36.33  -82.37       Tennessee         US
# 23      37.77 -122.22      California         US
# 24      39.18  -77.26        Maryland         US
# 25      39.38  -74.45      New Jersey         US
# 26      40.57 -122.36      California         US
# 27      33.86 -118.38      California         US
# 28      32.91  -80.04  South Carolina         US
# 29      36.21 -115.22          Nevada         US
# 30      42.58  -87.85       Wisconsin         US
# 31      32.77 -117.02      California         US
# ...       ...     ...             ...        ...
# 275264  41.84  -87.68        Illinois         US
# 275265  32.75  -97.34           Texas         US
# 275266  26.03  -80.16         Florida         US
# 275267  33.94 -117.40      California         US
# 275268  33.83 -116.46      California         US
# 275269  40.79  -74.03      New Jersey         US
# 275270  40.03  -75.28    Pennsylvania         US
# 275271  42.14  -72.76   Massachusetts         US
# 275272  39.20  -76.86        Maryland         US
# 275273  40.82  -96.69        Nebraska         US
# 275274  36.70  -76.64        Virginia         US
# 275275  41.31  -72.92     Connecticut         US
# 275276  33.91 -118.08      California         US
# 275277  40.67  -73.94        New York         US
# 275278  40.67  -73.94        New York         US
# 275279  40.07  -82.42            Ohio         US
# 275280  33.95  -83.39         Georgia         US
# 275281  36.56  -87.35       Tennessee         US
# 275282  40.79  -74.03      New Jersey         US
# 275283  36.17  -86.78       Tennessee         US
# 275284  37.01 -121.58      California         US
# 275285  27.99  -80.66         Florida         US
# 275286  41.26  -96.01        Nebraska         US
# 275287  40.01  -75.13    Pennsylvania         US
# 275288  29.66  -95.15           Texas         US
# 275289  41.53  -88.12        Illinois         US
# 275290  33.97 -118.15      California         US
# 275291  42.84  -78.75        New York         US
# 275292  37.90 -122.04      California         US
# 275293  41.84  -87.68        Illinois         US
#
#                              city_state  hour_of_day  month_of_year
# 0                      Buffalo_New York          3.0            5.0
# 1                   Lakeville_Minnesota         21.0            5.0
# 2                            Parma_Ohio         15.0            4.0
# 3           Fayetteville_North Carolina          7.0            5.0
# 4                       Fishers_Indiana         11.0            5.0
# 5                     New York_New York         12.0            4.0
# 7                           Dayton_Ohio         12.0            3.0
# 8                     Richmond_Virginia         12.0            4.0
# 9          Bloomfield Township_Michigan         13.0            4.0
# 10                 Des Plaines_Illinois         12.0            5.0
# 12                West Valley City_Utah          8.0            5.0
# 13               Culver City_California          8.0            3.0
# 14                  Milwaukee_Wisconsin         12.0            3.0
# 15              Deerfield Beach_Florida         13.0            3.0
# 16                     Chicago_Illinois         18.0            3.0
# 17                  Sheboygan_Wisconsin         15.0            3.0
# 18                    New York_New York         23.0            4.0
# 19                    New York_New York         10.0            5.0
# 20                         Mesa_Arizona          2.0            5.0
# 21                    Waukegan_Illinois         11.0            3.0
# 22               Johnson City_Tennessee         11.0            3.0
# 23                   Oakland_California         15.0            4.0
# 24                  Germantown_Maryland          7.0            5.0
# 25             Atlantic City_New Jersey         13.0            3.0
# 26                   Redding_California          8.0            3.0
# 27             Redondo Beach_California          6.0            5.0
# 28      North Charleston_South Carolina         11.0            4.0
# 29                     Las Vegas_Nevada          5.0            5.0
# 30                    Kenosha_Wisconsin          9.0            4.0
# 31                   La Mesa_California          5.0            5.0
# ...                                 ...          ...            ...
# 275264                 Chicago_Illinois         16.0            4.0
# 275265                 Fort Worth_Texas          8.0            5.0
# 275266                Hollywood_Florida         11.0            5.0
# 275267             Riverside_California          8.0            3.0
# 275268        Cathedral City_California          5.0            4.0
# 275269          North Bergen_New Jersey         18.0            5.0
# 275270        Lower Merion_Pennsylvania         17.0            3.0
# 275271          Westfield_Massachusetts         11.0            5.0
# 275272                Columbia_Maryland          9.0            4.0
# 275273                 Lincoln_Nebraska         14.0            5.0
# 275274                 Suffolk_Virginia         12.0            4.0
# 275275            New Haven_Connecticut         12.0            5.0
# 275276               Norwalk_California          9.0            4.0
# 275277                New York_New York         12.0            4.0
# 275278                New York_New York         23.0            5.0
# 275279                      Newark_Ohio          5.0            4.0
# 275280            Athens-Clarke_Georgia         13.0            5.0
# 275281            Clarksville_Tennessee          9.0            3.0
# 275282          North Bergen_New Jersey          9.0            3.0
# 275283              Nashville_Tennessee         16.0            3.0
# 275284                Gilroy_California         22.0            3.0
# 275285                 Palm Bay_Florida          8.0            5.0
# 275286                   Omaha_Nebraska         20.0            3.0
# 275287        Philadelphia_Pennsylvania         15.0            5.0
# 275288                   Pasadena_Texas         10.0            4.0
# 275289                  Joliet_Illinois         11.0            5.0
# 275290          Bell Gardens_California         23.0            3.0
# 275291             West Seneca_New York          1.0            4.0
# 275292          Walnut Creek_California          5.0            5.0
# 275293                 Chicago_Illinois         17.0            3.0
#
# [269757 rows x 17 columns]

# %%
import seaborn as sn
a4_dims = (11.7*2, 8.27)
fig, ax = plt.subplots(figsize=a4_dims)
ax = sn.distplot(a=cdf['lat'])
ax = sn.distplot(a=ucdf['lat'])
# ax.set_xticks(np.arange(0,31,1))
# ax.set_autoscaley_on(False)
# ax.set_xlim([0,40])
plt.show()
fig, ax = plt.subplots(figsize=a4_dims)
ax = sn.distplot(a=cdf['long'])
ax = sn.distplot(a=ucdf['long'])
# ax.set_xticks(np.arange(0,31,1))
# ax.set_autoscaley_on(False)
# ax.set_xlim([0,40])
plt.show()

# %%
# sn.barplot()
# cdf['city_state'].value_counts() / df['city_state'].value_counts()
# df['city_state'].value_counts()

# %%
# df['State'].value_counts()
def get_col_df(col: str, percents=True):
    coldf = pd.DataFrame(df.groupby(['test','converted'])[col].value_counts()).rename(columns={col:'count'}).reset_index()
    totals = coldf.groupby(['test','converted']).sum().reset_index().rename(columns={'count':'total'})[['test','converted', 'total']]
    coldf = coldf.merge(totals, on=['test','converted'])
    coldf['percentage'] = coldf['count'] / coldf.total
    label_df = pd.DataFrame()
    label_df['test'] = [0,1,0,1]
    label_df['converted'] = [0,1,1,0]
    label_df['group'] = ['control_not_converted', 'test_converted', 'control_converted', 'test_not_converted']
    coldf = coldf.merge(label_df, on=['test','converted'])
    return coldf

# %%
def plot_col_bars(col: str, hue:str, swap_axis=False, percents=True):
    a4_dims = [11.7*2, 8.27]
    if swap_axis:
        fig, ax = plt.subplots(figsize=reversed(a4_dims))
        sn.barplot(y=col, x='percentage', hue=hue, ax=ax, ci=None, data=get_col_df(col, percents))
    else:
        fig, ax = plt.subplots(figsize=a4_dims)
        sn.barplot(x=col, y='percentage', hue=hue, ax=ax, ci=None, data=get_col_df(col, percents))
    plt.show()

# %%
plot_col_bars('source', 'group')
plot_col_bars('State', 'group', True)

# %%
plot_col_bars('device', 'group')

# %%
plot_col_bars('operative_system', 'group')

# %%
plot_col_bars('hour_of_day', 'group')

# %%
plot_col_bars('month_of_year', 'group')
